# %% [markdown]
# ## Automação de Tarefas

# %% [markdown]
# ## Problema a ser resolvido
# - buscar automaticamente os dados das ações no site do Yahoo!
# - analisar os dados das ações de acordo com a solicitação do gesto
# - enviar um e-mail com todas análises de forma automática

# %% [markdown]
# ## Passo 1 - buscar automaticamente os dados das ações no site no Yahoo!

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\canal\anaconda3\lib\site-packages (0.2.37)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\canal\anaconda3\lib\site-packages (from yfinance) (2.1.4)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\canal\anaconda3\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\users\canal\anaconda3\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\canal\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\canal\anaconda3\lib\site-packages (from yfinance) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\canal\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in c:\users\canal\anaconda3\lib\site-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\canal\anaconda3\lib\site-packages (from yfinance) (2.4.0)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\canal\anaconda3\lib\site-packages (from yfinance) (3.17.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\canal\anaconda3\lib\site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in c:\users\canal\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\canal\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in c:\users\canal\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\canal\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\canal\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\canal\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\canal\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\canal\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\canal\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\canal\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2024.2.2)

# %%
import yfinance

# %%
codigo = input("Digite o código da ação desejada: ")
dados = yfinance.Ticker(codigo).history("6mo")

fechamento = dados.Close
fechamento.plot()
# Out:
# Digite o código da ação desejada:  BBSE3.SA
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Passo 2 - Análises Solicitadas Pelo Gestor
#
# - A análise dos últimos seis meses
# - Cotação máxima da ação
# - Cotação mínima da ação
# - Cotação atual

# %%
# cotação máxima
maxima = fechamento.max()
minima = fechamento.min()
atual = fechamento.iloc[-1]

# %% [markdown]
# ## Passo 3 - Automatizando O Envio de E-Mail
#
# - abrir uma nova aba (ctrl + t)
# - escrever o endereço do Gmail e apertar enter
# - clicar no botão escrever
# - preencher o destinatário, tab
# - preencher o assunto, tab
# - preencher o corpo do e-mail
# - clicar no botão ENVIAR

# %%
# instalando o PyautoGUI
# !pip install pyautogui
# !pip install pyperclip
# Out:
# Requirement already satisfied: pyautogui in c:\users\canal\anaconda3\lib\site-packages (0.9.54)
# Requirement already satisfied: pymsgbox in c:\users\canal\anaconda3\lib\site-packages (from pyautogui) (1.0.9)
# Requirement already satisfied: pytweening>=1.0.4 in c:\users\canal\anaconda3\lib\site-packages (from pyautogui) (1.2.0)
# Requirement already satisfied: pyscreeze>=0.1.21 in c:\users\canal\anaconda3\lib\site-packages (from pyautogui) (0.1.30)
# Requirement already satisfied: pygetwindow>=0.0.5 in c:\users\canal\anaconda3\lib\site-packages (from pyautogui) (0.0.9)
# Requirement already satisfied: mouseinfo in c:\users\canal\anaconda3\lib\site-packages (from pyautogui) (0.1.3)
# Requirement already satisfied: pyrect in c:\users\canal\anaconda3\lib\site-packages (from pygetwindow>=0.0.5->pyautogui) (0.2.0)
# Requirement already satisfied: Pillow>=9.3.0 in c:\users\canal\anaconda3\lib\site-packages (from pyscreeze>=0.1.21->pyautogui) (10.2.0)
# Requirement already satisfied: pyperclip in c:\users\canal\anaconda3\lib\site-packages (from mouseinfo->pyautogui) (1.8.2)
# Requirement already satisfied: pyperclip in c:\users\canal\anaconda3\lib\site-packages (1.8.2)

# %%
import pyautogui
import pyperclip

# %%
# configurando uma pausa entre os passos
pyautogui.PAUSE = 2

# abrir uma nova aba (ctrl + t)
pyautogui.hotkey("ctrl", "t")

# escrever o endereço do Gmail e apertar enter
pyperclip.copy("www.gmail.com")
pyautogui.click(x=541, y=52)
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("enter")

# clicar no botão escrever
pyautogui.click(x=172, y=197)

# preencher o destinatário, tab
pyperclip.copy("email@email.com")
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("tab")

# preencher o assunto, tab
pyperclip.copy("Análises Diárias")
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("tab")

#preencher o corpo do e-mail
mensagem = f"""
Prezado Gestor,

Seguem as análises dos últimos seis meses da ação {codigo} conforme solicitado:

Cotação máxima: R$ {round(maxima, 2)}
Cotação mínima: R$ {round(minima, 2)}
Cotação atual: R$ {round(atual, 2)}

Qualquer dúvida, estou à disposição!

Atte.
"""
pyperclip.copy(mensagem)
pyautogui.hotkey("ctrl", "v")

#clicar no botão ENVIAR
pyautogui.click(x=1316, y=1014)

# %%
import time

time.sleep(5)
pyautogui.position()
# Out:
# Point(x=1316, y=1014)
